# %%
import pandas
from matplotlib import pyplot
import numpy as np

file = pandas.read_csv("abalone.csv")

ages = file.loc[:, 'age'].to_numpy()


coclender = file.iloc[:, 4].to_numpy()
pyplot.plot(ages, coclender, 'bo')
