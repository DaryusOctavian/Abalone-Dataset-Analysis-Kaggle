# %%
import pandas
from matplotlib import pyplot
import numpy as np

file = pandas.read_csv("abalone.csv")

age = file.loc[:, 'age'].to_numpy()
coclender = (file.iloc[:, 3].to_numpy() + file.iloc[:, 4].to_numpy()) / 3

pyplot.plot(age, coclender, 'bo')
