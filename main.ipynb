# %%
import pandas
from matplotlib import pyplot
import numpy as np

file = pandas.read_csv("abalone.csv")

age = file.loc[:, 'age'].to_numpy()
wt = file.loc[:, 'whole_wt'].to_numpy()
coclender = file.iloc[:, 7].to_numpy()
coclender = wt - coclender

pyplot.plot(age, coclender, 'bo')
